# %% [markdown]
# <a href="https://colab.research.google.com/github/26405-netizen/10705/blob/main/20260908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
red = 1000
yellow = 2000
blue = 3000
green = 4000

red_count=int(input('빨간색 접시의 개수를 입력하세요'))
yellow_count=int(input('노란색 접시의 개수를 입력하세요'))
blue_count=int(input('파란색 접시의 개수를 입력하세요'))
green_count=int(input('초록색 접시의 개수를 입력하세요'))

r=red*red_count
y=yellow*yellow_count
b=blue*blue_count
g=green*green_count

print(f'=====회전 초밥 영수증=====\n  접시  단가  개수  합계\n 빨간색 {red}  {red_count}   {r}\n 노란색 {yellow}  {yellow_count}   {y}\n 파란색 {blue}  {blue_count}   {b}\n 초록색 {green}  {green_count}   {g}\n 합계            {r+y+b+g}\n=======================')
# Out:
# 빨간색 접시의 개수를 입력하세요2
# 노란색 접시의 개수를 입력하세요2
# 파란색 접시의 개수를 입력하세요2
# 초록색 접시의 개수를 입력하세요2
# =====회전 초밥 영수증=====
#   접시  단가  개수  합계
#  빨간색 1000  2   2000
#  노란색 2000  2   4000
#  파란색 3000  2   6000
#  초록색 4000  2   8000
#  합계            20000
# ...
