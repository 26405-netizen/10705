# %% [markdown]
# <a href="https://colab.research.google.com/github/26405-netizen/10705/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='hello '
b='world'
print(a+b)
print(a*3)
print(a<b)
print('h'in a)
print('wor'not in b)
# Out:
# hello world
# hello hello hello
# True
# True
# False

# %%
a='Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a='Hello Python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# Python
# Hello
# Py
# HloPt

# %%
a=input('주민번호 입력:')
b=a[0:2]
c=a[2:4]
d=a[4:6]
print(f'{b}년 {c}월 {d}일')
# Out:
# 주민번호 입력:101004
# 10년 10월 04일

# %%
a=input()
b=a[::-1]
b=b.replace('a','3')
b=b.replace('f','9')
b=b.replace('d','2')
b=b.replace('s','4')
print(b)
# Out:
# asdf
# 9243
